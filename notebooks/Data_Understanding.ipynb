# %%
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("saurabhshahane/twitter-sentiment-dataset")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in d:\social-media-analysis\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in d:\social-media-analysis\.venv\lib\site-packages (from kagglehub) (0.1.16)
# Requirement already satisfied: packaging in d:\social-media-analysis\.venv\lib\site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in d:\social-media-analysis\.venv\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in d:\social-media-analysis\.venv\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in d:\social-media-analysis\.venv\lib\site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in d:\social-media-analysis\.venv\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.33.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\social-media-analysis\.venv\lib\site-packages (from requests->kagglehub) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in d:\social-media-analysis\.venv\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\social-media-analysis\.venv\lib\site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\social-media-analysis\.venv\lib\site-packages (from requests->kagglehub) (2026.2.25)
# Requirement already satisfied: colorama in d:\social-media-analysis\.venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 5
#       2 import kagglehub
#       4 # Download latest version
# ----> 5 path = kagglehub.dataset_download("saurabhshahane/twitter-sentiment-dataset")
#       7 print("Path to dataset files:", path)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\http_resolver.py:125, in DatasetHttpResolver._resolve(self, h, path, force_download, output_dir)
#     123 with build_kaggle_client() as api_client:
#     124     if not h.is_versioned():
# --> 125         h = h.with_version(_get_current_version(api_client, h))
#     127     cache = Cache(override_dir=output_dir)
#     128     dataset_path = cache.load_from_cache(h, path)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\http_resolver.py:364, in _get_current_version(api_client, h)
#     362     r.owner_slug = h.owner
#     363     r.dataset_slug = h.dataset
# --> 364     dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365     return dataset.current_version_number
#     367 elif isinstance(h, NotebookHandle):
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      65 """Handle errors for handler NOT returning 200 status code on failure."""
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#      69     message = str(e)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglehub\http_resolver.py:364, in _get_current_version.<locals>.<lambda>()
#     362     r.owner_slug = h.owner
#     363     r.dataset_slug = h.dataset
# --> 364     dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365     return dataset.current_version_number
#     367 elif isinstance(h, NotebookHandle):
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:33, in DatasetApiClient.get_dataset(self, request)
#      30 if request is None:
#      31   request = ApiGetDatasetRequest()
# ---> 33 return self._client.call("datasets.DatasetApiService", "GetDataset", request, ApiDataset)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\kagglesdk\kaggle_http_client.py:96, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      93 if response_type is not None and (response_type == FileDownload or response_type == HttpRedirect):
#      94     settings["stream"] = True
# ---> 96 http_response = self._session.send(http_request, **settings)
#      98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File d:\Social-Media-Analysis\.venv\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File c:\python313\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/twitter_data.csv")

# %%
df.head()
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 162980 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  162976 non-null  str
#  1   category    162973 non-null  float64
# dtypes: float64(1), str(1)
# memory usage: 21.9 MB

# %%
print(df['category'].isnull().sum())
# Out:
# 7

# %%
df[df['category'].isnull()]
# Out:
#                                                clean_text  category
# 130448  the foundation stone northeast gas grid inaugu...       NaN
# 155642  dear terrorists you can run but you cant hide ...       NaN
# 155698  offense the best defence with mission shakti m...       NaN
# 155770  have always heard politicians backing out thei...       NaN
# 158693  modi government plans felicitate the faceless ...       NaN
# 159442               chidambaram gives praises modinomics       NaN
# 160559  the reason why modi contested from seats 2014 ...       NaN

# %%
df = df.dropna(subset=['category'])

# %%
df['category'] = df['category'].astype(int)

# %%
print(df['category'].value_counts())
# Out:
# category
#  1    72250
#  0    55213
# -1    35510
# Name: count, dtype: int64

# %%
df = df.rename(columns={
    'clean_text': 'text',
    'category': 'sentiment'
})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 162973 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   text       162969 non-null  str
#  1   sentiment  162973 non-null  int64
# dtypes: int64(1), str(1)
# memory usage: 23.1 MB

# %%
df.shape
# Out:
# (162973, 2)

# %%
df.to_csv("../data/cleaned_twitter_data.csv", index=False)
